# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
color = sns.color_palette()

import numpy as np
import pandas as pd

# %%
data = pd.read_csv('timeseriesdataset.csv')

data.head()
# Out:
#    Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 0    1     Sunday            1  9/14/2014      2,146         1,582
# 1    2     Monday            2  9/15/2014      3,621         2,528
# 2    3    Tuesday            3  9/16/2014      3,698         2,630
# 3    4  Wednesday            4  9/17/2014      3,667         2,614
# 4    5   Thursday            5  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236

# %%
data.shape
# Out:
# (2167, 8)

# %%
data.tail(20)
# Out:
#        Row        Day  Day.Of.Week       Date Page.Loads Unique.Visits  \
# 2147  2148     Friday            6  7/31/2020      3,005         2,317
# 2148  2149   Saturday            7   8/1/2020      2,305         1,750
# 2149  2150     Sunday            1   8/2/2020      2,696         1,993
# 2150  2151     Monday            2   8/3/2020      3,866         2,814
# 2151  2152    Tuesday            3   8/4/2020      3,826         2,845
# 2152  2153  Wednesday            4   8/5/2020      3,673         2,774
# 2153  2154   Thursday            5   8/6/2020      3,660         2,625
# 2154  2155     Friday            6   8/7/2020      3,136         2,364
# 2155  2156   Saturday            7   8/8/2020      2,223         1,628
# 2156  2157     Sunday            1   8/9/2020      2,623         1,941
# 2157  2158     Monday            2  8/10/2020      3,638         2,745
# 2158  2159    Tuesday            3  8/11/2020      3,740         2,742
# 2159  2160  Wednesday            4  8/12/2020      3,767         2,904
# 2160  2161   Thursday            5  8/13/2020      3,621         2,780
# 2161  2162     Friday            6  8/14/2020      2,971         2,308
# 2162  2163   Saturday            7  8/15/2020      2,221         1,696
# 2163  2164     Sunday            1  8/16/2020      2,724         2,037
# 2164  2165     Monday            2  8/17/2020      3,456         2,638
# 2165  2166    Tuesday            3  8/18/2020      3,581         2,683
# 2166  2167  Wednesday            4  8/19/2020      2,064         1,564
#
#      First.Time.Visits Returning.Visits
# 2147             1,887              430
# 2148             1,479              271
# 2149             1,701              292
# 2150             2,368              446
# 2151             2,400              445
# 2152             2,334              440
# 2153             2,189              436
# 2154             1,941              423
# 2155             1,354              274
# 2156             1,644              297
# 2157             2,325              420
# 2158             2,258              484
# 2159             2,477              427
# 2160             2,322              458
# 2161             1,922              386
# 2162             1,373              323
# 2163             1,686              351
# 2164             2,181              457
# 2165             2,184              499
# 2166             1,297              267

# %%
data.sample()
# Out:
#     Unnamed: 0  YearsExperience   Salary
# 16          16              5.2  66030.0

# %%
data.sample(30)
# Out:
#        Row        Day  Day.Of.Week        Date Page.Loads Unique.Visits  \
# 1892  1893    Tuesday            3  11/19/2019      6,607         4,772
# 662    663   Thursday            5    7/7/2016      3,729         2,700
# 953    954     Monday            2   4/24/2017      5,489         4,083
# 498    499     Monday            2   1/25/2016      4,638         3,205
# 1422  1423     Monday            2    8/6/2018      4,319         2,856
# 2152  2153  Wednesday            4    8/5/2020      3,673         2,774
# 730    731    Tuesday            3   9/13/2016      4,788         3,625
# 613    614   Thursday            5   5/19/2016      5,849         4,211
# 1844  1845  Wednesday            4   10/2/2019      5,143         3,683
# 1286  1287     Friday            6   3/23/2018      4,364         2,994
# 1509  1510   Thursday            5   11/1/2018      6,044         3,988
# 378    379     Sunday            1   9/27/2015      3,141         2,291
# 1168  1169   Saturday            7  11/25/2017      2,391         1,652
# 1448  1449   Saturday            7    9/1/2018      1,731         1,241
# 2027  2028   Thursday            5    4/2/2020      4,933         3,838
# 838    839     Friday            6  12/30/2016      2,273         1,541
# 1788  1789  Wednesday            4    8/7/2019      3,702         2,675
# 625    626    Tuesday            3   5/31/2016      5,775         4,216
# 1990  1991    Tuesday            3   2/25/2020      5,496         4,210
# 1740  1741   Thursday            5   6/20/2019      3,716         2,615
# 1418  1419   Thursday            5    8/2/2018      4,194         2,754
# 1485  1486     Monday            2   10/8/2018      6,045         4,310
# 848    849     Monday            2    1/9/2017      4,182         2,841
# 1743  1744     Sunday            1   6/23/2019      2,344         1,621
# 409    410  Wednesday            4  10/28/2015      5,906         4,266
# 363    364   Saturday            7   9/12/2015      2,042         1,429
# 645    646     Monday            2   6/20/2016      4,954         3,522
# 860    861   Saturday            7   1/21/2017      2,481         1,778
# 1761  1762   Thursday            5   7/11/2019      3,765         2,669
# 585    586   Thursday            5   4/21/2016      6,254         4,537
#
#      First.Time.Visits Returning.Visits
# 1892             4,119              653
# 662              2,148              552
# 953              3,252              831
# 498              2,649              556
# 1422             2,233              623
# 2152             2,334              440
# 730              2,992              633
# 613              3,484              727
# 1844             3,209              474
# 1286             2,457              537
# 1509             3,299              689
# 378              1,980              311
# 1168             1,327              325
# 1448               989              252
# 2027             3,305              533
# 838              1,164              377
# 1788             2,215              460
# 625              3,413              803
# 1990             3,601              609
# 1740             2,137              478
# 1418             2,202              552
# 1485             3,659              651
# 848              2,191              650
# 1743             1,317              304
# 409              3,614              652
# 363              1,223              206
# 645              2,829              693
# 860              1,437              341
# 1761             2,150              519
# 585              3,707              830

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
data.describe()
# Out:
#                Row  Day.Of.Week
# count  2167.000000  2167.000000
# mean   1084.000000     3.997231
# std     625.703338     2.000229
# min       1.000000     1.000000
# 25%     542.500000     2.000000
# 50%    1084.000000     4.000000
# 75%    1625.500000     6.000000
# max    2167.000000     7.000000

# %%
data.isnull().sum()
# Out:
# Row                  0
# Day                  0
# Day.Of.Week          0
# Date                 0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %%
import pandas as pd
import numpy as np
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])
numeric_cols.fillna(numeric_cols.mean(), inplace=True) 
data = pd.concat([numeric_cols, non_numeric_cols], axis=1)
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Row                  0
# Day.Of.Week          0
# Day                  0
# Date                 0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %%
data.shape
# Out:
# (2167, 8)

# %%
data.dropna(inplace=True)
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Row                  0
# Day.Of.Week          0
# Day                  0
# Date                 0
# Page.Loads           0
# Unique.Visits        0
# First.Time.Visits    0
# Returning.Visits     0
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data.shape
# Out:
# (2167, 8)

# %%
numeric_cols = data.select_dtypes(include=[np.number])
Q1 = numeric_cols.quantile(0.25)
Q3 = numeric_cols.quantile(0.75)
IQR = Q3 - Q1
data_cleaned = data[~((numeric_cols < (Q1 - 1.5 * IQR)) | (numeric_cols > (Q3 + 1.5 * IQR))).any(axis=1)]
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
numeric_cols.boxplot()
plt.title("Before Outlier Removal")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 2)
data_cleaned.select_dtypes(include=[np.number]).boxplot()
plt.title("After Outlier Removal")

plt.tight_layout()
plt.show()

# %%
data_cleaned.shape
# Out:
# (2167, 8)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])
scaler = MinMaxScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)
scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)
scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)
print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (2167, 8)
#
# ************************************************************
#         Row  Day.Of.Week        Day       Date Page.Loads Unique.Visits  \
# 0  0.000000     0.000000     Sunday  9/14/2014      2,146         1,582
# 1  0.000462     0.166667     Monday  9/15/2014      3,621         2,528
# 2  0.000923     0.333333    Tuesday  9/16/2014      3,698         2,630
# 3  0.001385     0.500000  Wednesday  9/17/2014      3,667         2,614
# 4  0.001847     0.666667   Thursday  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

numeric_cols = data.select_dtypes(include=[np.number])
non_numeric_cols = data.select_dtypes(exclude=[np.number])
scaler = StandardScaler()
scaled_numeric_data = scaler.fit_transform(numeric_cols)
scaled_numeric_df = pd.DataFrame(scaled_numeric_data, columns=numeric_cols.columns)
scaled_data = pd.concat([scaled_numeric_df, non_numeric_cols.reset_index(drop=True)], axis=1)
print(scaled_data.shape)
print()
print('*' * 60)
scaled_data.head()
# Out:
# (2167, 8)
#
# ************************************************************
#         Row  Day.Of.Week        Day       Date Page.Loads Unique.Visits  \
# 0 -1.731252    -1.498790     Sunday  9/14/2014      2,146         1,582
# 1 -1.729653    -0.998732     Monday  9/15/2014      3,621         2,528
# 2 -1.728055    -0.498674    Tuesday  9/16/2014      3,698         2,630
# 3 -1.726456     0.001385  Wednesday  9/17/2014      3,667         2,614
# 4 -1.724857     0.501443   Thursday  9/18/2014      3,316         2,366
#
#   First.Time.Visits Returning.Visits
# 0             1,430              152
# 1             2,297              231
# 2             2,352              278
# 3             2,327              287
# 4             2,130              236
